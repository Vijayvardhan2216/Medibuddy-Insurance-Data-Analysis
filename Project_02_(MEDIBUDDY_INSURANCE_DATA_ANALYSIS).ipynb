# %% [markdown]
# # **Project Name** - **MEDIBUDDY INSURANCE DATA ANALYSIS**

# %% [markdown]
# - ##### **Project Type**    - Exploratory Data Analysis (EDA)
# - ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary** - **Medibuddy Insurance Data Analysis**

# %% [markdown]
# #**Medibuddy Insurance Data Analysis**
#
# - **Project Objective :**
#   - To analyze MediBuddy insurance data to identify the key factors influencing medical insurance claim amounts.
#   - To support data-driven decisions for policy pricing, risk assessment and wellness-based incentives.
#
# - **Data Overview :**
#   - Two datasets were used and merged using Policy Number:
#     - **Personal Details :** Number of dependents, smoking status, region
#     - **Health & Policy Data :** Age, gender, BMI, insurance charges
#   - Final dataset enabled a comprehensive view of demographic, lifestyle and health factors affecting claims.
#
# - **Methodology & Tools :**
#
#   **1. Excel :**
#     - Initial data inspection and validation
#     - Understanding distributions and summary statistics
#
#   **2. Python (Pandas, NumPy, Scikit-learn) :**
#     - Data cleaning and merging
#     - Exploratory Data Analysis (EDA)
#     - Feature encoding and transformation
#     - Machine learning model development
#
#   **3. Machine Learning :**
#     - Built a Random Forest Regressor to predict insurance charges
#     - Evaluated using R² score and Mean Absolute Error (MAE)
#
# - **Key Findings – Lifestyle & Health Impact :**
#   - Smoking status is the strongest driver of insurance cost; smokers incur 2–3× higher claims than non-smokers.
#   - BMI shows a strong positive correlation with claim amounts; higher BMI leads to higher medical expenses.
#   - These two factors together form the primary risk indicators for insurance pricing.
#
# - **Key Findings – Demographics :**
#   - Age has a gradual but consistent impact, with higher claims observed among older policyholders.
#   - Number of dependents increases claim amounts, indicating higher utilization of healthcare services.
#   - Gender does not show a significant difference in claims and should not be used as a policy constraint.
#
# - **Key Findings – Geographic Patterns :**
#   - Moderate variation in average claims across regions was observed.
#   - Indicates potential value in region-based pricing or localized wellness initiatives.
#
# - **Model Performance :**
#   - **Model Used :** Random Forest Regressor
#   - **R² Score :** 0.86
#   - **Mean Absolute Error :** ~₹2,580
#   - Demonstrates strong predictive accuracy for real-world insurance cost estimation.
#
# - **Actionable Recommendations :**
#   - Introduce risk-based pricing using smoking status and BMI as primary factors.
#   - Offer health-based discounts and wellness incentives to customers with healthy BMI levels.
#   - Apply region-aware premium adjustments where claim variations are consistently higher.
#   - Avoid gender-based discrimination in policy approvals.
#
# - **Business Impact :**
#   - Enables fairer underwriting and accurate premium prediction.
#   - Helps reduce claim risk through preventive health strategies.
#   - Improves profitability while promoting customer wellness and trust.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Vijayvardhan2216/Medibuddy-Insurance-Data-Analysis.git

# %% [markdown]
# # **Problem Statement -**

# %% [markdown]
# - **Core Challenge :** MediBuddy faces the challenge of accurately assessing insurance risk and pricing policies due to variations in customer health, lifestyle and demographic profiles. Without clear insights, the company risks either underpricing high-risk customers or overpricing low-risk ones.
#
# - **Cost Variability Issues :** This challenge manifests in significant differences in insurance claim amounts caused by multiple factors:
#   - **High Medical Claims :** Customers with certain health and lifestyle characteristics (such as smoking and high BMI) tend to generate disproportionately higher claim amounts.
#   - **Uncertain Risk Drivers :** It is unclear which factors—age, BMI, smoking status, dependents, gender, or location—contribute most to increased insurance costs.
#
# - **Impact on Stakeholders :**
#   - **For Policyholders :** Lack of personalized pricing leads to unfair premiums, where low-risk customers may subsidize high-risk individuals.
#   - **For MediBuddy :** Inaccurate risk assessment results in higher claim payouts, reduced profitability and limited ability to design targeted wellness programs.
#   - **For the Insurance Ecosystem :**
#   Absence of predictive insights restricts proactive healthcare planning and preventive interventions.
#
# - **Analytical Goal :** The objective is to leverage data analytics and machine learning to identify the key drivers of insurance claim costs, quantify their impact and build an accurate predictive model. These insights aim to support risk-based pricing, health-driven discounts and improved underwriting decisions, enabling MediBuddy to balance profitability with customer fairness.

# %% [markdown]
# #### **Define Your Business Objective ?**

# %% [markdown]
# - **Maximize Trip Completion Rates:** The primary objective is to reduce the number of unfulfilled requests (Cancellations and No Cars Available) to ensure that a higher percentage of rider demands are successfully met.
#
# - **Optimize Revenue Generation:** By bridging the supply-demand gap, Uber can capture lost revenue from the 58% of requests that currently go unfulfilled, directly increasing the company's bottom line.
#
# - **Improve Operational Efficiency:** Identify specific peak hours and locations of failure to allow for better driver distribution and resource allocation, ensuring drivers are where the demand is highest.
#
# - **Enhance Customer Satisfaction and Loyalty:** Reducing wait times and the frequency of "No Cars Available" messages improves the reliability of the service, fostering trust and long-term loyalty among airport commuters.
#
# - **Develop Data-Driven Strategies:** Provide actionable insights for management to implement targeted interventions, such as dynamic pricing, driver incentives and optimized shift scheduling, to balance the marketplace effectively.

# %% [markdown]
# # **General Guidelines -**

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
# Data handling and analysis
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning – preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Machine Learning – models
from sklearn.ensemble import RandomForestRegressor

# Model evaluation
from sklearn.metrics import r2_score, mean_absolute_error

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
# Load required libraries
import pandas as pd

# Load the datasets
personal_df = pd.read_excel("/content/Medibuddy Insurance Data Personal Details (1).xlsx")
health_df = pd.read_excel("/content/Medibuddy Insurance Data Price (2).xlsx")

# Display first few rows to verify
personal_df.head(), health_df.head()

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
# View first few rows of each dataset
personal_df.head()

# %%
# Dataset First Look
# View first few rows of each dataset
health_df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
# Check number of rows and columns in each dataset
personal_df.shape

# %%
# Dataset Rows & Columns count
# Check number of rows and columns in each dataset
health_df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
# Get detailed information about each dataset
personal_df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Check and remove duplicate values from both datasets

# Check duplicates
personal_duplicates = personal_df.duplicated().sum()
health_duplicates = health_df.duplicated().sum()

print("Duplicate rows in Personal Details Dataset:", personal_duplicates)
print("Duplicate rows in Health & Policy Dataset:", health_duplicates)

# Remove duplicates if any
personal_df = personal_df.drop_duplicates()
health_df = health_df.drop_duplicates()

print("Duplicates removed successfully (if any).")

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Check missing (null) values in both datasets

# Count missing values
personal_missing = personal_df.isnull().sum()
health_missing = health_df.isnull().sum()

print("Missing values in Personal Details Dataset:\n", personal_missing)
print("\nMissing values in Health & Policy Dataset:\n", health_missing)

# (Optional) Drop rows with missing values if any
personal_df = personal_df.dropna()
health_df = health_df.dropna()

print("\nMissing values handled successfully (if any).")

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# - **Summary of Dataset Findings**
#   - **Size :** The dataset contains insurance records with multiple features covering health, lifestyle and demographic details for each policyholder.
#   - **Quality :** No duplicate entries were found; the data is clean and consistent after preprocessing.
#   - **Missing Data :** No significant missing or null values were observed in critical fields after cleaning, ensuring reliability for analysis.
#   - **Feature Composition :** The dataset includes both numerical variables (age, BMI, dependents, insurance charges) and categorical variables (gender, smoking status, region).
#   - **Key Risk Drivers :** Smoking status and BMI emerge as the most influential factors affecting insurance claim amounts.
#   - **Cost Patterns :** Insurance charges increase with age and number of dependents, while gender shows minimal impact.
#   - **Geographic Variation:** Moderate variation in claim amounts across regions suggests potential for region-based pricing strategies.
#   - **Analytical Focus:** The study centers on identifying cost drivers and building a predictive model to support risk-based pricing and fair underwriting decisions.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Merge both datasets using Policy Number
df = pd.merge(health_df, personal_df, on="Policy no.")

# Understanding dataset variables

# Display column names
print("Columns in Dataset:\n", df.columns)

# Display data types
print("\nData Types:\n", df.dtypes)

# Separate numerical and categorical variables
numerical_features = df.select_dtypes(include=['int64','float64']).columns
categorical_features = df.select_dtypes(include=['object']).columns

print("\nNumerical Variables:", numerical_features)
print("\nCategorical Variables:", categorical_features)

# Show statistical summary of numerical variables
print("\nStatistical Summary:\n", df.describe())

# %% [markdown]
# ### Variables Description

# %%
# Create a data dictionary for MediBuddy Insurance Dataset

variable_description = {
    "Policy no.": "Unique identifier for each insurance policy used to merge datasets",
    "Age": "Age of the policyholder in years",
    "Sex": "Gender of the policyholder (Male/Female)",
    "BMI": "Body Mass Index indicating health condition",
    "Children": "Number of dependents covered under the policy",
    "Smoker": "Indicates whether the policyholder is a smoker (Yes/No)",
    "Region": "Geographic region of the policyholder",
    "Charges (INR)": "Total medical insurance claim amount (Target Variable)"
}

# Display variable descriptions
for key, value in variable_description.items():
    print(f"{key}: {value}")

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check unique values for each column

for column in df.columns:
    print(f"\nUnique values in {column}:")
    print(df[column].unique())

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# -----------------------------
# DATA WRANGLING
# -----------------------------

# 1. Merge both datasets
df = pd.merge(health_df, personal_df, on="Policy no.")

# 2. Rename columns for consistency
df.rename(columns={
    "Policy no.": "policy_no",
    "sex": "gender",
    "bmi": "bmi",
    "charges in INR": "charges",
    "children": "children",
    "smoker": "smoker",
    "region": "region",
    "age": "age"
}, inplace=True)

# 3. Convert categorical values to consistent format
df['gender'] = df['gender'].str.lower()
df['smoker'] = df['smoker'].str.lower()
df['region'] = df['region'].str.lower()

# 4. Check and remove duplicates
df = df.drop_duplicates()

# 5. Check and remove missing values
df = df.dropna()

# 6. Reset index
df = df.reset_index(drop=True)

# 7. Final dataset shape
print("Final Dataset Shape:", df.shape)

# View cleaned dataset
df.head()

# %% [markdown]
# What all manipulations have you done and insights you found?

# %% [markdown]
# - **Data Manipulations Performed :**
#   - Merged two datasets (health and personal details) using Policy Number.
#   - Renamed columns for consistency and ease of use.
#   - Converted categorical text (gender, smoker, region) into standardized lowercase format.
#   - Checked and removed duplicate records.
#   - Checked and handled missing values.
#   - Identified and separated numerical and categorical variables.
#   - Encoded categorical variables for machine learning.
#   - Split data into training and testing sets.
#   - Built and evaluated a Random Forest Regression model.
#
# - **Key Insights Discovered :**
#   - Smoking status is the most influential factor — smokers have significantly higher insurance claims.
#   - BMI has a strong positive relationship with insurance charges; higher BMI leads to higher medical costs.
#   - Age shows a gradual increase in insurance cost, especially after middle age.
#   - Number of dependents increases the total claim amount.
#   - Gender has very little impact on insurance charges.
#   - Geographic region shows moderate cost differences, suggesting regional pricing opportunities.
#   - The machine learning model achieved 86% accuracy (R² = 0.86), proving that customer health and lifestyle data can reliably predict insurance costs.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load the datasets
personal_df = pd.read_excel("/content/Medibuddy Insurance Data Personal Details (1).xlsx")
health_df = pd.read_excel("/content/Medibuddy Insurance Data Price (2).xlsx")

# Merge both datasets
df = pd.merge(health_df, personal_df, on="Policy no.")

# Create BMI vs Insurance Charges scatter plot
plt.figure(figsize=(8,6))
plt.scatter(df['bmi'], df['charges in INR'])
plt.xlabel("BMI")
plt.ylabel("Insurance Charges (INR)")
plt.title("BMI vs Insurance Charges")

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1. **scatter plot** is ideal for showing the relationship between **two numerical variables**.
# 2. **BMI** and **insurance charges** are both continuous values.
# 3. It helps identify whether there is a **correlation** between BMI and cost.
# 4. The chart makes it easy to spot **trends, patterns, and outliers**.
# 5. It visually shows that **higher BMI leads to higher insurance charges**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. There is a **positive relationship** between BMI and insurance charges.
# 2. Customers with **higher BMI** tend to have **higher medical expenses**.
# 3. People with **normal BMI** generally have **lower insurance costs**.
# 4. The risk of high claims increases as BMI moves into the **overweight and obese** range.
# 5. BMI can be used as a **strong indicator for pricing, risk assessment, and health-based discounts**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# 1. Helps identify **high-risk customers** using BMI, smoking status, and age.
# 2. Enables **risk-based premium pricing**, improving profitability.
# 3. Supports **health-based discounts**, encouraging preventive care.
# 4. Improves **customer fairness** by avoiding overpricing of low-risk users.
# 5. Enhances **claim prediction accuracy** using machine learning.
#
# ---
#
# **⚠️ Negative Growth Risks :**
#
# 1. **Ignoring smoking and BMI** leads to underpricing high-risk customers.
# 2. High-risk customers generate **unexpected claim losses**.
# 3. Flat pricing causes **healthy customers to leave** due to unfair premiums.
# 4. Poor risk assessment increases **financial instability**.
#
# ---
#
# - **Conclusion :**
#
#   * Acting on these insights allows MediBuddy to implement **fair, profitable, and data-driven insurance pricing**.
#   * Ignoring them leads to **higher claim payouts, revenue loss and customer dissatisfaction**.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load the datasets
personal_df = pd.read_excel("/content/Medibuddy Insurance Data Personal Details (1).xlsx")
health_df = pd.read_excel("/content/Medibuddy Insurance Data Price (2).xlsx")

# Merge both datasets
df = pd.merge(health_df, personal_df, on="Policy no.")

# Create Smoker vs Insurance Charges box plot
plt.figure(figsize=(8,6))

smoker_charges = df[df['smoker'] == 'yes']['charges in INR']
nonsmoker_charges = df[df['smoker'] == 'no']['charges in INR']

plt.boxplot([smoker_charges, nonsmoker_charges], labels=['Smoker', 'Non-Smoker'])
plt.xlabel("Smoking Status")
plt.ylabel("Insurance Charges (INR)")
plt.title("Smoker vs Insurance Charges")

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1. A **box plot** is ideal for comparing **distributions between two categories**.
# 2. Smoking status is a **categorical variable** (Smoker vs Non-Smoker).
# 3. Insurance charges are **numerical**, making box plots perfect for comparison.
# 4. It clearly shows **differences in median, spread and outliers** between the two groups.
# 5. The chart makes it easy to identify that **smokers have much higher insurance costs** than non-smokers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Smokers have significantly higher insurance charges** compared to non-smokers.
# 2. The **median claim amount** for smokers is much higher than that of non-smokers.
# 3. Smokers show a **wider spread of costs**, meaning their medical expenses are more unpredictable.
# 4. Non-smokers have **lower and more stable insurance claims**.
# 5. Smoking is a **major risk factor** and should be a key variable in insurance pricing and policy design.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# 1. Helps identify **high-risk customers (smokers)**.
# 2. Enables **risk-based premium pricing**.
# 3. Supports **fair discounts for non-smokers**.
# 4. Improves **profitability and claim control**.
#
# ---
#
# **⚠️ Negative Growth Risks :**
#
# 1. **Underpricing smokers** leads to financial losses.
# 2. **Overpricing non-smokers** can cause customer churn.
# 3. High and unpredictable smoker claims increase **risk exposure**.
#
# ---
#
# - **Conclusion :**
#
#   * Acting on these insights enables **fair pricing and higher profitability**.
#   * Ignoring them results in **revenue loss, customer dissatisfaction and higher claim risk**.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets
personal_df = pd.read_excel("/content/Medibuddy Insurance Data Personal Details (1).xlsx")
health_df = pd.read_excel("/content/Medibuddy Insurance Data Price (2).xlsx")

# Merge datasets
df = pd.merge(health_df, personal_df, on="Policy no.")

# Create Age vs Insurance Charges scatter plot
plt.figure(figsize=(8,6))
plt.scatter(df['age'], df['charges in INR'])
plt.xlabel("Age")
plt.ylabel("Insurance Charges (INR)")
plt.title("Age vs Insurance Charges")

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1. A **scatter plot** is ideal for showing the relationship between two **continuous numerical variables**.
# 2. **Age** and **insurance charges** are both numerical and continuous.
# 3. It helps identify whether insurance cost **increases or decreases with age**.
# 4. The chart makes **trends, patterns, and outliers** easy to observe.
# 5. It clearly shows that **insurance charges tend to rise as age increases**, supporting age-based risk assessment.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. There is a **positive relationship** between age and insurance charges.
# 2. **Younger policyholders** generally have **lower medical expenses**.
# 3. **Insurance costs increase** as customers get older.
# 4. Older individuals show **greater variability in claims**, indicating higher health risk.
# 5. Age is an important factor for **risk-based pricing and policy planning**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# 1. Helps identify **high-cost age groups**.
# 2. Enables **age-based premium structuring**.
# 3. Supports **better risk assessment** for older customers.
# 4. Improves **long-term financial planning** for MediBuddy.
#
# ---
#
# **⚠️ Negative Growth Risks :**
#
# 1. **Underpricing older customers** leads to higher claim losses.
# 2. **Overpricing younger customers** can cause customer churn.
# 3. Ignoring age-based trends increases **pricing inaccuracy**.
#
# ---
#
# - **Conclusion :**
#
#   * Acting on these insights leads to **fair pricing and controlled claim costs**.
#   * Ignoring them results in **revenue loss, customer dissatisfaction and financial risk**.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets
personal_df = pd.read_excel("/content/Medibuddy Insurance Data Personal Details (1).xlsx")
health_df = pd.read_excel("/content/Medibuddy Insurance Data Price (2).xlsx")

# Merge both datasets
df = pd.merge(health_df, personal_df, on="Policy no.")

# Group by number of children (dependents) and calculate average charges
dependents_cost = df.groupby("children")["charges in INR"].mean()

# Create bar chart
plt.figure(figsize=(8,6))
dependents_cost.plot(kind="bar")
plt.xlabel("Number of Dependents (Children)")
plt.ylabel("Average Insurance Charges (INR)")
plt.title("Dependents vs Average Insurance Charges")

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1. A **bar chart** is ideal for comparing **numerical values across discrete categories**.
# 2. The **number of dependents (children)** is a discrete variable (0, 1, 2, 3, …).
# 3. **Average insurance charges** are numerical and suitable for comparison.
# 4. It clearly shows how **cost changes as family size increases**.
# 5. The chart makes it easy to identify that **more dependents lead to higher insurance costs**, supporting family-based pricing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Insurance charges **increase as the number of dependents increases**.
# 2. Families with **more children** generate **higher medical expenses**.
# 3. Policies with **zero or one dependent** have relatively **lower costs**.
# 4. Large families show **higher average claim amounts**.
# 5. The number of dependents is an important factor for **family plan pricing and risk assessment**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# 1. Helps identify **high-cost family groups**.
# 2. Enables **family-based premium pricing**.
# 3. Supports **accurate risk assessment** for large households.
# 4. Improves **policy design for family insurance plans**.
#
# ---
#
# **⚠️ Negative Growth Risks :**
#
# 1. **Underpricing large families** leads to higher claim payouts.
# 2. **Overpricing small families** can cause customer churn.
# 3. Ignoring dependent-based costs results in **unfair pricing and financial risk**.
#
# ---
#
# - **Conclusion :**
#
#   * Using these insights enables **fair family pricing and controlled claim costs**.
#   * Ignoring them leads to **revenue loss, customer dissatisfaction and higher financial risk**.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets
personal_df = pd.read_excel("/content/Medibuddy Insurance Data Personal Details (1).xlsx")
health_df = pd.read_excel("/content/Medibuddy Insurance Data Price (2).xlsx")

# Merge both datasets
df = pd.merge(health_df, personal_df, on="Policy no.")

# Group by region and calculate average charges
region_cost = df.groupby("region")["charges in INR"].mean()

# Create bar chart
plt.figure(figsize=(8,6))
region_cost.plot(kind="bar")
plt.xlabel("Region")
plt.ylabel("Average Insurance Charges (INR)")
plt.title("Region vs Average Insurance Charges")

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1. A **bar chart** is ideal for comparing **numerical values across multiple categories**.
# 2. **Region** is a categorical variable with multiple groups.
# 3. **Average insurance charges** are numerical and easy to compare using bars.
# 4. The chart clearly shows **which regions have higher or lower costs**.
# 5. It helps identify **geographic risk patterns** for location-based pricing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Insurance charges **vary across different regions**.
# 2. Some regions have **higher average medical costs** than others.
# 3. This indicates that **geographic location influences healthcare expenses**.
# 4. Customers in high-cost regions represent **higher financial risk**.
# 5. Region can be used for **location-based pricing and policy customization**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# 1. Helps identify **high-cost geographic regions**.
# 2. Enables **region-based premium pricing**.
# 3. Supports **better cost control and risk management**.
# 4. Improves **profitability through location-aware pricing**.
#
# ---
#
# **⚠️ Negative Growth Risks :**
#
# 1. **Underpricing high-cost regions** leads to financial losses.
# 2. **Overpricing low-cost regions** can cause customer churn.
# 3. Ignoring regional differences increases **pricing inaccuracy**.
#
# ---
#
# - **Conclusion :**
#
#   * Using these insights allows MediBuddy to implement **fair and profitable location-based pricing**.
#   * Ignoring them leads to **revenue loss, customer dissatisfaction and higher claim risk**.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 7 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets
personal_df = pd.read_excel("/content/Medibuddy Insurance Data Personal Details (1).xlsx")
health_df = pd.read_excel("/content/Medibuddy Insurance Data Price (2).xlsx")

# Merge both datasets
df = pd.merge(health_df, personal_df, on="Policy no.")

# Create box plot for Gender vs Insurance Charges
plt.figure(figsize=(8,6))

male_charges = df[df['sex'] == 'male']['charges in INR']
female_charges = df[df['sex'] == 'female']['charges in INR']

plt.boxplot([male_charges, female_charges], labels=['Male', 'Female'])
plt.xlabel("Gender")
plt.ylabel("Insurance Charges (INR)")
plt.title("Gender vs Insurance Charges")

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1. A **box plot** is ideal for comparing **numerical distributions across categories**.
# 2. **Gender** is a categorical variable (Male and Female).
# 3. **Insurance charges** are numerical values that vary across individuals.
# 4. The chart clearly shows **median, spread, and outliers** for both genders.
# 5. It helps determine whether **gender has a significant impact on insurance cost**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Insurance charges for **male and female customers are very similar**.
# 2. There is **no significant difference** in the median claim amount between genders.
# 3. Both genders show a **similar spread and range** of insurance costs.
# 4. Gender does **not appear to be a strong risk factor** for medical expenses.
# 5. Insurance pricing should **not be based on gender**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# 1. Ensures **fair and unbiased pricing** across genders.
# 2. Helps MediBuddy **comply with ethical and regulatory standards**.
# 3. Builds **customer trust and brand reputation**.
# 4. Prevents loss of customers due to **gender-based discrimination**.
#
# ---
#
# **⚠️ Negative Growth Risks :**
#
# 1. **Using gender for pricing** can lead to legal and compliance risks.
# 2. Gender-based pricing may cause **customer dissatisfaction and churn**.
# 3. It can damage **brand image and trust**.
#
# ---
#
# **Conclusion :**
#
#   * Using these insights promotes **fairness, compliance and long-term customer loyalty**.
#   * Ignoring them may lead to **reputation damage, customer loss and regulatory issues**.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets
personal_df = pd.read_excel("/content/Medibuddy Insurance Data Personal Details (1).xlsx")
health_df = pd.read_excel("/content/Medibuddy Insurance Data Price (2).xlsx")

# Merge datasets
df = pd.merge(health_df, personal_df, on="Policy no.")

# Create BMI categories
df['bmi_category'] = pd.cut(df['bmi'],
                            bins=[0, 18.5, 24.9, 29.9, 100],
                            labels=['Underweight', 'Normal', 'Overweight', 'Obese'])

# Calculate average charges per BMI category
bmi_cost = df.groupby('bmi_category')['charges in INR'].mean()

# Plot bar chart
plt.figure(figsize=(8,6))
bmi_cost.plot(kind='bar')
plt.xlabel("BMI Category")
plt.ylabel("Average Insurance Charges (INR)")
plt.title("BMI Category vs Average Insurance Charges")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1. A **bar chart** is ideal for comparing **average values across groups**.
# 2. BMI categories convert raw BMI numbers into **meaningful health groups**.
# 3. It allows easy comparison between **Underweight, Normal, Overweight, and Obese** customers.
# 4. The chart clearly shows how **health condition impacts insurance cost**.
# 5. It supports **wellness-based pricing and discount strategies**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Obese customers** have the **highest average insurance charges**.
# 2. **Overweight customers** also incur higher costs than normal-weight individuals.
# 3. **Normal BMI** customers have the **lowest insurance charges**.
# 4. Insurance cost **increases as BMI category worsens**.
# 5. BMI category is a strong indicator of **health risk and medical expense**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# 1. Helps identify **high-risk BMI groups**.
# 2. Enables **health-based premium pricing**.
# 3. Supports **discounts for healthy customers**.
# 4. Encourages **preventive healthcare and wellness programs**.
#
# ---
#
# **⚠️ Negative Growth Risks :**
#
# 1. **Ignoring BMI categories** leads to underpricing high-risk customers.
# 2. **Overpricing healthy customers** may cause customer churn.
# 3. High-BMI groups can cause **higher claim losses** if not priced correctly.
#
# ---
#
# - **Conclusion :**
#
#   * Using these insights enables **fair, health-based pricing and lower claim risk**.
#   * Ignoring them leads to **revenue loss, higher medical payouts and reduced profitability**.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets
personal_df = pd.read_excel("/content/Medibuddy Insurance Data Personal Details (1).xlsx")
health_df = pd.read_excel("/content/Medibuddy Insurance Data Price (2).xlsx")

# Merge datasets
df = pd.merge(health_df, personal_df, on="Policy no.")

# Create BMI categories
df['bmi_category'] = pd.cut(df['bmi'],
                            bins=[0, 18.5, 24.9, 29.9, 100],
                            labels=['Underweight', 'Normal', 'Overweight', 'Obese'])

# Calculate average charges grouped by Smoker and BMI Category
grouped = df.groupby(['smoker', 'bmi_category'])['charges in INR'].mean().unstack()

# Plot grouped bar chart
plt.figure(figsize=(10,6))
grouped.plot(kind='bar')
plt.xlabel("Smoking Status")
plt.ylabel("Average Insurance Charges (INR)")
plt.title("Smoker & BMI Category vs Average Insurance Charges")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1. It combines **two major risk factors** — smoking status and BMI — in one analysis.
# 2. A **grouped bar chart** makes it easy to compare multiple categories at once.
# 3. It shows how **lifestyle (smoking)** and **health condition (BMI)** interact to affect costs.
# 4. The chart clearly highlights **high-risk groups** such as obese smokers.
# 5. It supports **advanced risk-based pricing and underwriting decisions**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Smokers with high BMI (overweight or obese)** have the **highest insurance charges**.
# 2. **Non-smokers with normal BMI** have the **lowest medical costs**.
# 3. Smoking **amplifies the financial risk** of high BMI.
# 4. BMI and smoking together have a **compounding effect** on insurance expenses.
# 5. Customers with both unhealthy lifestyle and poor health represent the **highest insurance risk**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# 1. Helps identify **highest-risk customer groups** (obese smokers).
# 2. Enables **highly accurate risk-based pricing**.
# 3. Supports **targeted wellness and smoking-cessation programs**.
# 4. Reduces **claim losses and improves profitability**.
#
# ---
#
# **⚠️ Negative Growth Risks :**
#
# 1. **Ignoring combined risk factors** leads to severe underpricing.
# 2. High-risk groups can cause **large claim payouts**.
# 3. Poor risk segmentation increases **financial instability**.
#
# ---
#
# - **Conclusion :**
#
#   * Using these insights allows MediBuddy to implement **precise, profitable and fair pricing strategies**.
#   * Ignoring them results in **higher claim losses, revenue leakage and reduced sustainability**.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets
personal_df = pd.read_excel("/content/Medibuddy Insurance Data Personal Details (1).xlsx")
health_df = pd.read_excel("/content/Medibuddy Insurance Data Price (2).xlsx")

# Merge datasets
df = pd.merge(health_df, personal_df, on="Policy no.")

# Group by Children and Smoker
grouped = df.groupby(['children', 'smoker'])['charges in INR'].mean().unstack()

# Plot grouped bar chart
plt.figure(figsize=(10,6))
grouped.plot(kind='bar')
plt.xlabel("Number of Dependents (Children)")
plt.ylabel("Average Insurance Charges (INR)")
plt.title("Children & Smoking Status vs Average Insurance Charges")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1. It combines **family size** and **lifestyle risk** in one analysis.
# 2. A **grouped bar chart** allows easy comparison across multiple categories.
# 3. It shows how **smoking behavior affects insurance cost within different family sizes**.
# 4. The chart highlights **high-risk segments** such as smokers with multiple dependents.
# 5. It supports **family-based and lifestyle-based pricing strategies**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Smokers have higher insurance charges** than non-smokers across all family sizes.
# 2. Insurance costs **increase as the number of dependents increases**.
# 3. **Smokers with more children** represent the **highest-cost group**.
# 4. Non-smokers with fewer dependents have the **lowest insurance expenses**.
# 5. Family size and smoking together create a **compounding effect on medical costs**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# 1. Helps identify **high-risk family groups** (smokers with dependents).
# 2. Enables **family and lifestyle-based premium pricing**.
# 3. Supports **targeted wellness and smoking-cessation programs**.
# 4. Improves **claim risk control and profitability**.
#
# ---
#
# **⚠️ Negative Growth Risks :**
#
# 1. **Ignoring smoker + dependents risk** leads to underpricing.
# 2. High-risk families may cause **large claim payouts**.
# 3. Flat pricing increases **financial losses**.
#
# ---
#
# - **Conclusion :**
#
#   * Using these insights enables **accurate risk-based family pricing and sustainable growth**.
#   * Ignoring them leads to **revenue loss, higher claim costs and reduced profitability**.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets
personal_df = pd.read_excel("/content/Medibuddy Insurance Data Personal Details (1).xlsx")
health_df = pd.read_excel("/content/Medibuddy Insurance Data Price (2).xlsx")

# Merge datasets
df = pd.merge(health_df, personal_df, on="Policy no.")

# Create Age Groups
df['age_group'] = pd.cut(df['age'],
                         bins=[0, 25, 40, 60, 100],
                         labels=['Young (0–25)', 'Adult (26–40)', 'Middle Age (41–60)', 'Senior (60+)'])

# Calculate average insurance charges by age group
age_cost = df.groupby('age_group')['charges in INR'].mean()

# Plot bar chart
plt.figure(figsize=(8,6))
age_cost.plot(kind='bar')
plt.xlabel("Age Group")
plt.ylabel("Average Insurance Charges (INR)")
plt.title("Age Group vs Average Insurance Charges")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1. It converts raw age values into **meaningful age groups**.
# 2. A **bar chart** is ideal for comparing **average values across categories**.
# 3. It helps identify **high-cost and low-cost age segments**.
# 4. The chart simplifies **risk-based policy planning**.
# 5. It supports **age-based pricing and product design**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Senior and middle-aged customers** have the **highest insurance charges**.
# 2. **Young customers** have the **lowest medical costs**.
# 3. Insurance cost **increases as age group increases**.
# 4. Middle-aged groups show **rising health risk**.
# 5. Age grouping is useful for **pricing and underwriting decisions**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# 1. Helps identify **high-cost age segments**.
# 2. Enables **age-based premium pricing**.
# 3. Supports **better risk management**.
# 4. Improves **long-term financial planning**.
#
# ---
#
# **⚠️ Negative Growth Risks :**
#
# 1. **Underpricing older age groups** leads to claim losses.
# 2. **Overpricing younger groups** can cause customer churn.
# 3. Ignoring age-based risk results in **pricing inefficiency**.
#
# ---
#
# - **Conclusion :**
#
#   * Using these insights allows MediBuddy to apply **fair, age-based pricing and control medical costs**.
#   * Ignoring them leads to **revenue loss, dissatisfaction and financial risk**.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets
personal_df = pd.read_excel("/content/Medibuddy Insurance Data Personal Details (1).xlsx")
health_df = pd.read_excel("/content/Medibuddy Insurance Data Price (2).xlsx")

# Merge datasets
df = pd.merge(health_df, personal_df, on="Policy no.")

# Group by Region and Smoker
grouped = df.groupby(['region', 'smoker'])['charges in INR'].mean().unstack()

# Plot grouped bar chart
plt.figure(figsize=(10,6))
grouped.plot(kind='bar')
plt.xlabel("Region")
plt.ylabel("Average Insurance Charges (INR)")
plt.title("Region & Smoking Status vs Average Insurance Charges")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1. It combines **geographic risk** and **lifestyle risk** in one analysis.
# 2. A **grouped bar chart** makes it easy to compare multiple categories.
# 3. It shows how **smoking impacts insurance cost within each region**.
# 4. The chart highlights **high-risk regions with high smoker costs**.
# 5. It supports **region-wise and lifestyle-based pricing strategies**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Smokers have higher insurance charges** than non-smokers in every region.
# 2. Some regions show **higher overall medical costs**.
# 3. **Smokers in high-cost regions** represent the **highest financial risk**.
# 4. Non-smokers in low-cost regions have the **lowest insurance expenses**.
# 5. Region and smoking together create **significant variation in insurance cost**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# 1. Helps identify **high-risk regions with high smoker population**.
# 2. Enables **location and lifestyle-based premium pricing**.
# 3. Supports **better underwriting and risk control**.
# 4. Improves **profitability through precise segmentation**.
#
# ---
#
# **⚠️ Negative Growth Risks :**
#
# 1. **Ignoring regional smoker risk** leads to underpricing.
# 2. High-risk regions can generate **large claim payouts**.
# 3. Flat pricing increases **financial instability**.
#
# ---
#
# - **Conclusion :**
#
#   * Using these insights allows MediBuddy to apply **accurate, fair and profitable pricing strategies**.
#   * Ignoring them leads to **revenue loss, higher medical payouts and reduced sustainability**.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets
personal_df = pd.read_excel("/content/Medibuddy Insurance Data Personal Details (1).xlsx")
health_df = pd.read_excel("/content/Medibuddy Insurance Data Price (2).xlsx")

# Merge datasets
df = pd.merge(health_df, personal_df, on="Policy no.")

# Create Age Groups
df['age_group'] = pd.cut(df['age'],
                         bins=[0, 25, 40, 60, 100],
                         labels=['Young (0–25)', 'Adult (26–40)', 'Middle Age (41–60)', 'Senior (60+)'])

# Group by Age Group and Smoker
grouped = df.groupby(['age_group', 'smoker'])['charges in INR'].mean().unstack()

# Plot grouped bar chart
plt.figure(figsize=(10,6))
grouped.plot(kind='bar')
plt.xlabel("Age Group")
plt.ylabel("Average Insurance Charges (INR)")
plt.title("Age Group & Smoking Status vs Average Insurance Charges")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1. It combines **two major risk factors** — age and smoking.
# 2. A **grouped bar chart** allows easy comparison across multiple categories.
# 3. It shows how **smoking impacts different age groups**.
# 4. The chart highlights **high-risk segments** such as older smokers.
# 5. It supports **age-based and lifestyle-based pricing decisions**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Smokers have higher insurance charges** across all age groups.
# 2. **Older smokers** incur the **highest medical costs**.
# 3. Insurance charges **increase with age**.
# 4. Smoking **amplifies age-related health risk**.
# 5. Age and smoking together create **very high financial risk segments**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# 1. Helps identify **highest-risk age–smoker groups**.
# 2. Enables **highly accurate premium pricing**.
# 3. Supports **targeted wellness and smoking-cessation programs**.
# 4. Improves **claim control and profitability**.
#
# ---
#
# **⚠️ Negative Growth Risks :**
#
# 1. **Ignoring age and smoking risk** leads to underpricing.
# 2. High-risk groups can cause **large claim payouts**.
# 3. Flat pricing results in **financial instability**.
#
# ---
#
# - **Conclusion :**
#
#   * Using these insights enables **precise risk-based pricing and sustainable growth**.
#   * Ignoring them leads to **revenue loss, high medical payouts and reduced profitability**.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets
personal_df = pd.read_excel("/content/Medibuddy Insurance Data Personal Details (1).xlsx")
health_df = pd.read_excel("/content/Medibuddy Insurance Data Price (2).xlsx")

# Merge datasets
df = pd.merge(health_df, personal_df, on="Policy no.")

# Create BMI categories
df['bmi_category'] = pd.cut(df['bmi'],
                            bins=[0, 18.5, 24.9, 29.9, 100],
                            labels=['Underweight', 'Normal', 'Overweight', 'Obese'])

# Group by Children and BMI Category
grouped = df.groupby(['children', 'bmi_category'])['charges in INR'].mean().unstack()

# Plot grouped bar chart
plt.figure(figsize=(10,6))
grouped.plot(kind='bar')
plt.xlabel("Number of Dependents (Children)")
plt.ylabel("Average Insurance Charges (INR)")
plt.title("Children & BMI Category vs Average Insurance Charges")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1. It combines **family size** and **health risk** in one analysis.
# 2. A **grouped bar chart** allows easy comparison across multiple BMI categories and family sizes.
# 3. It shows how **BMI impacts insurance cost within different family sizes**.
# 4. The chart highlights **high-risk groups** such as obese customers with dependents.
# 5. It supports **family-based and health-based pricing strategies**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Insurance charges increase as the number of dependents increases**.
# 2. **Obese and overweight customers** have higher costs across all family sizes.
# 3. Families with **obese members and multiple dependents** incur the **highest expenses**.
# 4. **Normal BMI families** have the **lowest insurance charges**.
# 5. Family size and BMI together create a **compounding effect on medical costs**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **✅ Positive Business Impact :**
#
# 1. Helps identify **high-risk families** (obese members with dependents).
# 2. Enables **family and health-based premium pricing**.
# 3. Supports **targeted wellness and weight-management programs**.
# 4. Improves **claim risk control and profitability**.
#
# ---
#
# **⚠️ Negative Growth Risks :**
#
# 1. **Ignoring BMI and dependents risk** leads to underpricing.
# 2. High-risk families can generate **large medical payouts**.
# 3. Flat pricing causes **financial losses**.
#
# ---
#
# - **Conclusion :**
#
#   * Using these insights allows MediBuddy to apply **accurate, fair and profitable family health pricing**.
#   * Ignoring them leads to **revenue loss, higher claim costs and reduced business sustainability**.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load datasets
personal_df = pd.read_excel("/content/Medibuddy Insurance Data Personal Details (1).xlsx")
health_df = pd.read_excel("/content/Medibuddy Insurance Data Price (2).xlsx")

# Merge datasets
df = pd.merge(health_df, personal_df, on="Policy no.")

# Convert categorical smoker to numeric for correlation
df['smoker_numeric'] = df['smoker'].map({'yes':1, 'no':0})

# Select numerical columns for correlation
corr_data = df[['age', 'bmi', 'children', 'smoker_numeric', 'charges in INR']]

# Compute correlation matrix
corr_matrix = corr_data.corr()

# Plot heatmap
plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap – Insurance Risk Factors")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1. A **correlation heatmap** shows the **strength and direction of relationships** between numerical variables.
# 2. It allows quick identification of **which factors influence insurance charges the most**.
# 3. It compares **multiple variables at once** in a single visual.
# 4. Strong correlations highlight **key risk drivers** like smoking, BMI, and age.
# 5. It supports **feature selection and model building** for machine learning.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Smoking status** has the **strongest positive correlation** with insurance charges.
# 2. **BMI** also shows a **high positive correlation** with insurance cost.
# 3. **Age** has a **moderate positive correlation** with charges.
# 4. **Number of children** has a **weaker but positive relationship** with insurance cost.
# 5. These correlations confirm that **lifestyle and health factors** are the primary drivers of insurance expenses.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load datasets
personal_df = pd.read_excel("/content/Medibuddy Insurance Data Personal Details (1).xlsx")
health_df = pd.read_excel("/content/Medibuddy Insurance Data Price (2).xlsx")

# Merge datasets
df = pd.merge(health_df, personal_df, on="Policy no.")

# Convert smoker to numeric for coloring
df['smoker_numeric'] = df['smoker'].map({'yes': 1, 'no': 0})

# Select relevant numerical columns
pairplot_data = df[['age', 'bmi', 'children', 'charges in INR', 'smoker_numeric']]

# Create pair plot
sns.pairplot(pairplot_data, hue='smoker_numeric')
plt.suptitle("Pair Plot – Relationship Between Key Insurance Variables", y=1.02)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1. A **pair plot** allows visualization of **multiple variable relationships at once**.
# 2. It shows how **age, BMI, dependents, smoking, and charges** interact with each other.
# 3. It helps identify **correlations, patterns, and outliers**.
# 4. Coloring by smoking status highlights **risk-based group differences**.
# 5. It supports **feature selection and deeper data exploration** for modeling.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Insurance charges increase with BMI and age** across the dataset.
# 2. **Smokers form a distinct high-cost cluster**, clearly separated from non-smokers.
# 3. **BMI and smoking together** show strong influence on high medical costs.
# 4. Customers with **higher BMI and older age** tend to have **higher insurance charges**.
# 5. The plot also highlights **outliers** with extremely high medical expenses, which are mostly smokers.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Yo achieve its business objective of **accurate pricing, risk control and improved profitability**, MediBuddy should adopt a **data-driven, risk-based insurance strategy**.
#
# - **Key recommendations :**
#
#   * **Use smoking status and BMI as primary pricing factors** since they are the strongest predictors of high insurance costs.
#   * **Implement age-based and family-size-based premium slabs** to fairly price different customer segments.
#   * **Apply region-based adjustments** where medical costs are consistently higher.
#   * **Offer health-based discounts** for customers with normal BMI and non-smoking status to promote wellness and reduce future claims.
#   * **Deploy the machine learning model** to predict insurance charges for new customers, enabling dynamic and accurate premium estimation.

# %% [markdown]
# # **Conclusion -**

# %% [markdown]
# This project successfully demonstrated how **data analytics and machine learning** can be used to improve insurance pricing, risk management, and customer fairness at MediBuddy. By analyzing key factors such as **BMI, smoking status, age, number of dependents, gender and region**, we identified the primary drivers of insurance costs and their impact on claim amounts.
#
# The study showed that **lifestyle and health factors (smoking and BMI)** are the strongest predictors of high medical expenses, while **age and family size** also play important roles. **Gender was found to have minimal impact**, supporting fair and unbiased policy decisions. The machine learning model further strengthened these insights by accurately predicting insurance charges, enabling data-driven premium estimation.
#
# Overall, the project provides MediBuddy with a **powerful decision-making framework** to implement **risk-based pricing, wellness incentives, and fair underwriting**, helping the company improve profitability, customer satisfaction and long-term sustainability.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
